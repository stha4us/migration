# %% [markdown]
# ## A Random Person

# %%
import json as json
import random as random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from generator.person import *

# %%
with open("data/world-countries.json", 'r') as f1:
    world = json.load(f1)

# %%
with open("data/nepal-province-district.json", 'r') as f2:
    nepal = json.load(f2)

# %%
with open("data/profession.json", 'r') as f3:
    prof = json.load(f3)

# %%
Data = []
for k in range(100):
    P = Person()
    P.set_ID()
    P.set_age()
    P.set_home_address(nepal)
    P.set_foreign_address(world)
    P.set_profession(prof)    

    Data.append({"ID": P.ID,\
                 "age" : P.age,\
                 "home_address" : P.home_address,\
                 "foreign_address": P.foreign_address,\
                 "profession": P.profession})

# %%
Data
# Out:
# [{'ID': '0',
#   'age': 50,
#   'home_address': {'province': 'PN6', 'district': 'Humla'},
#   'foreign_address': 'South Korea',
#   'profession': {'major': 'IT', 'branch': 'Software'}},
#  {'ID': '2',
#   'age': 48,
#   'home_address': {'province': 'PN6', 'district': 'Humla'},
#   'foreign_address': 'Lesotho',
#   'profession': {'major': 'Teaching', 'branch': 'English'}},
#  {'ID': 'K',
#   'age': 40,
#   'home_address': {'province': 'PN7', 'district': 'Baitadi'},
#   'foreign_address': 'Syria',
#   'profession': {'major': 'Agriculture', 'branch': 'Sugarcane'}},
#  {'ID': '2',
#   'age': 37,
#   'home_address': {'province': 'PN1', 'district': 'Sankhauasabha'},
#   'foreign_address': 'South Sudan',
#   'profession': {'major': 'Business', 'branch': 'Food Industry'}},
#  {'ID': '8',
#   'age': 37,
#   'home_address': {'province': 'PN4', 'district': 'Kaski'},
#   'foreign_address': 'Croatia',
#   'profession': {'major': 'Research', 'branch': 'Physics'}},
#  {'ID': '5',
#   'age': 31,
#   'home_address': {'province': 'PN3', 'district': 'Rasuwa'},
#   'foreign_address': 'Greece',
#   'profession': {'major': 'Research', 'branch': 'Physics'}},
#  {'ID': 'H',
#   'age': 49,
#   'home_address': {'province': 'PN2', 'district': 'Bara'},
#   'foreign_address': 'Argentina',
#   'profession': {'major': 'IT', 'branch': 'Software'}},
#  {'ID': 'S',
#   'age': 49,
#   'home_address': {'province': 'PN1', 'district': 'Khotang'},
#   'foreign_address': 'Switzerland',
#   'profession': {'major': 'Teaching', 'branch': 'Physics'}},
#  {'ID': '3',
#   'age': 27,
#   'home_address': {'province': 'PN2', 'district': 'Bara'},
#   'foreign_address': 'Papua New Guinea',
#   'profession': {'major': 'Research', 'branch': 'Physics'}},
#  {'ID': 'H',
#   'age': 36,
#   'home_address': {'province': 'PN4', 'district': 'Baglung'},
#   'foreign_address': 'United Kingdom',
#   'profession': {'major': 'Agriculture', 'branch': 'Vegetable'}},
#  {'ID': '0',
#   'age': 41,
#   'home_address': {'province': 'PN4', 'district': 'Manang'},
#   'foreign_address': 'East Timor',
#   'profession': {'major': 'Doctor', 'branch': 'Cancer'}},
#  {'ID': '8',
#   'age': 34,
#   'home_address': {'province': 'PN7', 'district': 'Doti'},
#   'foreign_address': 'Moldova',
#   'profession': {'major': 'Research', 'branch': 'Chemistry'}},
#  {'ID': '7',
#   'age': 36,
#   'home_address': {'province': 'PN7', 'district': 'Kailali'},
#   'foreign_address': 'Slovenia',
#   'profession': {'major': 'Teaching', 'branch': 'Math'}},
#  {'ID': 'A',
#   'age': 31,
#   'home_address': {'province': 'PN6', 'district': 'Dailekh'},
#   'foreign_address': 'Iceland',
#   'profession': {'major': 'Research', 'branch': 'Math'}},
#  {'ID': '0',
#   'age': 44,
#   'home_address': {'province': 'PN2', 'district': 'Dhanusha'},
#   'foreign_address': 'Iraq',
#   'profession': {'major': 'Doctor', 'branch': 'Cancer'}},
#  {'ID': 'C',
#   'age': 45,
#   'home_address': {'province': 'PN3', 'district': 'Ramechaap'},
#   'foreign_address': 'Turkmenistan',
#   'profession': {'major': 'IT', 'branch': 'Full Stack'}},
#  {'ID': '1',
#   'age': 30,
#   'home_address': {'province': 'PN2', 'district': 'Saptari'},
#   'foreign_address': 'Iraq',
#   'profession': {'major': 'Teaching', 'branch': 'English'}},
#  {'ID': 'U',
#   'age': 40,
#   'home_address': {'province': 'PN7', 'district': 'Bajura'},
#   'foreign_address': 'Denmark',
#   'profession': {'major': 'Research', 'branch': 'Physics'}},
#  {'ID': '1',
#   'age': 28,
#   'home_address': {'province': 'PN1', 'district': 'Jhapa'},
#   'foreign_address': 'Uruguay',
#   'profession': {'major': 'Research', 'branch': 'Physics'}},
#  {'ID': '4',
#   'age': 31,
#   'home_address': {'province': 'PN1', 'district': 'Panchthar'},
#   'foreign_address': 'Bosnia and Herzegovina',
#   'profession': {'major': 'Agriculture', 'branch': 'Sugarcane'}},
#  {'ID': 'U',
#   'age': 26,
#   'home_address': {'province': 'PN3', 'district': 'Chitwan'},
#   'foreign_address': 'Fiji',
#   'profession': {'major': 'IT', 'branch': 'Cloud Computing'}},
#  {'ID': 'K',
#   'age': 35,
#   'home_address': {'province': 'PN2', 'district': 'Rautahat'},
#   'foreign_address': 'Georgia',
#   'profession': {'major': 'IT', 'branch': 'Full Stack'}},
#  {'ID': 'P',
#   'age': 35,
#   'home_address': {'province': 'PN6', 'district': 'Humla'},
#   'foreign_address': 'New Caledonia',
#   'profession': {'major': 'Teaching', 'branch': 'Math'}},
#  {'ID': 'A',
#   'age': 45,
#   'home_address': {'province': 'PN1', 'district': 'Jhapa'},
#   'foreign_address': 'Uganda',
#   'profession': {'major': 'Doctor', 'branch': 'Cancer'}},
#  {'ID': '0',
#   'age': 50,
#   'home_address': {'province': 'PN1', 'district': 'Okhaldhunga'},
#   'foreign_address': 'India',
#   'profession': {'major': 'Teaching', 'branch': 'Math'}},
#  {'ID': '3',
#   'age': 31,
#   'home_address': {'province': 'PN1', 'district': 'Udayapur'},
#   'foreign_address': 'Malawi',
#   'profession': {'major': 'Teaching', 'branch': 'Physics'}},
#  {'ID': 'S',
#   'age': 25,
#   'home_address': {'province': 'PN7', 'district': 'Kailali'},
#   'foreign_address': 'Switzerland',
#   'profession': {'major': 'Research', 'branch': 'Chemistry'}},
#  {'ID': '4',
#   'age': 30,
#   'home_address': {'province': 'PN3', 'district': 'Bhaktapur'},
#   'foreign_address': 'Macedonia',
#   'profession': {'major': 'Business', 'branch': 'Stationary'}},
#  {'ID': 'T',
#   'age': 26,
#   'home_address': {'province': 'PN5', 'district': 'Rupandehi'},
#   'foreign_address': 'Benin',
#   'profession': {'major': 'Doctor', 'branch': 'Cancer'}},
#  {'ID': 'N',
#   'age': 45,
#   'home_address': {'province': 'PN4', 'district': 'Nawalpur'},
#   'foreign_address': 'Kyrgyzstan',
#   'profession': {'major': 'Agriculture', 'branch': 'Sugarcane'}},
#  {'ID': 'L',
#   'age': 28,
#   'home_address': {'province': 'PN1', 'district': 'Terhathum'},
#   'foreign_address': 'Qatar',
#   'profession': {'major': 'Doctor', 'branch': 'Vetenary'}},
#  {'ID': 'I',
#   'age': 49,
#   'home_address': {'province': 'PN6', 'district': 'Western_Rukum'},
#   'foreign_address': 'Central African Republic',
#   'profession': {'major': 'Business', 'branch': 'Food Industry'}},
#  {'ID': '8',
#   'age': 50,
#   'home_address': {'province': 'PN1', 'district': 'Terhathum'},
#   'foreign_address': 'Iceland',
#   'profession': {'major': 'Agriculture', 'branch': 'Sugarcane'}},
#  {'ID': '5',
#   'age': 37,
#   'home_address': {'province': 'PN6', 'district': 'Humla'},
#   'foreign_address': 'Democratic Republic of the Congo',
#   'profession': {'major': 'Agriculture', 'branch': 'Vegetable'}},
#  {'ID': '0',
#   'age': 48,
#   'home_address': {'province': 'PN5', 'district': 'Arghakhanchi'},
#   'foreign_address': 'Guinea',
#   'profession': {'major': 'IT', 'branch': 'Full Stack'}},
#  {'ID': 'A',
#   'age': 44,
#   'home_address': {'province': 'PN1', 'district': 'Solukhumbu'},
#   'foreign_address': 'Liberia',
#   'profession': {'major': 'Teaching', 'branch': 'English'}},
#  {'ID': '7',
#   'age': 30,
#   'home_address': {'province': 'PN4', 'district': 'Lamjung'},
#   'foreign_address': 'Costa Rica',
#   'profession': {'major': 'Agriculture', 'branch': 'Sugarcane'}},
#  {'ID': 'G',
#   'age': 34,
#   'home_address': {'province': 'PN4', 'district': 'Tanahun'},
#   'foreign_address': 'French Southern and Antarctic Lands',
#   'profession': {'major': 'Research', 'branch': 'Physics'}},
#  {'ID': '5',
#   'age': 43,
#   'home_address': {'province': 'PN5', 'district': 'Rupandehi'},
#   'foreign_address': 'Greenland',
#   'profession': {'major': 'Agriculture', 'branch': 'Goat Farm'}},
#  {'ID': '0',
#   'age': 46,
#   'home_address': {'province': 'PN6', 'district': 'Jumla'},
#   'foreign_address': 'Swaziland',
#   'profession': {'major': 'Research', 'branch': 'Math'}},
#  {'ID': '7',
#   'age': 44,
#   'home_address': {'province': 'PN3', 'district': 'Makwanpur'},
#   'foreign_address': 'Paraguay',
#   'profession': {'major': 'Teaching', 'branch': 'Math'}},
#  {'ID': 'W',
#   'age': 26,
#   'home_address': {'province': 'PN1', 'district': 'Sankhauasabha'},
#   'foreign_address': 'India',
#   'profession': {'major': 'Business', 'branch': 'Stationary'}},
#  {'ID': 'G',
#   'age': 39,
#   'home_address': {'province': 'PN4', 'district': 'Baglung'},
#   'foreign_address': 'South Sudan',
#   'profession': {'major': 'Teaching', 'branch': 'Physics'}},
#  {'ID': '2',
#   'age': 31,
#   'home_address': {'province': 'PN1', 'district': 'Sankhauasabha'},
#   'foreign_address': 'Lebanon',
#   'profession': {'major': 'IT', 'branch': 'Software'}},
#  {'ID': '7',
#   'age': 49,
#   'home_address': {'province': 'PN6', 'district': 'Jumla'},
#   'foreign_address': 'Mali',
#   'profession': {'major': 'Research', 'branch': 'Math'}},
#  {'ID': 'A',
#   'age': 45,
#   'home_address': {'province': 'PN5', 'district': 'Eastern_Rukum'},
#   'foreign_address': 'Japan',
#   'profession': {'major': 'Agriculture', 'branch': 'Sugarcane'}},
#  {'ID': '4',
#   'age': 36,
#   'home_address': {'province': 'PN6', 'district': 'Dolpa'},
#   'foreign_address': 'Greece',
#   'profession': {'major': 'IT', 'branch': 'Cloud Computing'}},
#  {'ID': '8',
#   'age': 38,
#   'home_address': {'province': 'PN3', 'district': 'Ramechaap'},
#   'foreign_address': 'Kosovo',
#   'profession': {'major': 'Agriculture', 'branch': 'Sugarcane'}},
#  {'ID': 'A',
#   'age': 42,
#   'home_address': {'province': 'PN5', 'district': 'Palpa'},
#   'foreign_address': 'Armenia',
#   'profession': {'major': 'Teaching', 'branch': 'English'}},
#  {'ID': 'K',
#   'age': 45,
#   'home_address': {'province': 'PN5', 'district': 'Palpa'},
#   'foreign_address': 'Antarctica',
#   'profession': {'major': 'Doctor', 'branch': 'Cancer'}},
#  {'ID': '2',
#   'age': 32,
#   'home_address': {'province': 'PN4', 'district': 'Baglung'},
#   'foreign_address': 'Australia',
#   'profession': {'major': 'Research', 'branch': 'Physics'}},
#  {'ID': 'L',
#   'age': 50,
#   'home_address': {'province': 'PN6', 'district': 'Kalikot'},
#   'foreign_address': 'Moldova',
#   'profession': {'major': 'Teaching', 'branch': 'Math'}},
#  {'ID': 'U',
#   'age': 50,
#   'home_address': {'province': 'PN6', 'district': 'Surkhet'},
#   'foreign_address': 'Finland',
#   'profession': {'major': 'Doctor', 'branch': 'Vetenary'}},
#  {'ID': 'Y',
#   'age': 46,
#   'home_address': {'province': 'PN3', 'district': 'Makwanpur'},
#   'foreign_address': 'Burkina Faso',
#   'profession': {'major': 'IT', 'branch': 'Full Stack'}},
#  {'ID': '5',
#   'age': 35,
#   'home_address': {'province': 'PN5', 'district': 'Bardiya'},
#   'foreign_address': 'Sweden',
#   'profession': {'major': 'Research', 'branch': 'Physics'}},
#  {'ID': 'M',
#   'age': 29,
#   'home_address': {'province': 'PN2', 'district': 'Dhanusha'},
#   'foreign_address': 'Vietnam',
#   'profession': {'major': 'Research', 'branch': 'Chemistry'}},
#  {'ID': 'W',
#   'age': 34,
#   'home_address': {'province': 'PN4', 'district': 'Lamjung'},
#   'foreign_address': 'Russia',
#   'profession': {'major': 'Teaching', 'branch': 'Physics'}},
#  {'ID': '1',
#   'age': 38,
#   'home_address': {'province': 'PN4', 'district': 'Gorkha'},
#   'foreign_address': 'Ethiopia',
#   'profession': {'major': 'IT', 'branch': 'Software'}},
#  {'ID': 'Z',
#   'age': 28,
#   'home_address': {'province': 'PN3', 'district': 'Bhaktapur'},
#   'foreign_address': 'Vietnam',
#   'profession': {'major': 'IT', 'branch': 'Software'}},
#  {'ID': '2',
#   'age': 43,
#   'home_address': {'province': 'PN6', 'district': 'Kalikot'},
#   'foreign_address': 'Lithuania',
#   'profession': {'major': 'IT', 'branch': 'Full Stack'}},
#  {'ID': '6',
#   'age': 32,
#   'home_address': {'province': 'PN4', 'district': 'Lamjung'},
#   'foreign_address': 'United Arab Emirates',
#   'profession': {'major': 'Business', 'branch': 'Food Industry'}},
#  {'ID': '7',
#   'age': 47,
#   'home_address': {'province': 'PN6', 'district': 'Mugu'},
#   'foreign_address': 'Jordan',
#   'profession': {'major': 'IT', 'branch': 'Full Stack'}},
#  {'ID': 'Q',
#   'age': 45,
#   'home_address': {'province': 'PN4', 'district': 'Kaski'},
#   'foreign_address': 'Indonesia',
#   'profession': {'major': 'Research', 'branch': 'Physics'}},
#  {'ID': 'X',
#   'age': 40,
#   'home_address': {'province': 'PN7', 'district': 'Dadeldhura'},
#   'foreign_address': 'Philippines',
#   'profession': {'major': 'Business', 'branch': 'Stationary'}},
#  {'ID': '2',
#   'age': 28,
#   'home_address': {'province': 'PN4', 'district': 'Manang'},
#   'foreign_address': 'Ivory Coast',
#   'profession': {'major': 'Business', 'branch': 'Food Industry'}},
#  {'ID': '2',
#   'age': 25,
#   'home_address': {'province': 'PN5', 'district': 'Kapilvastu'},
#   'foreign_address': 'Latvia',
#   'profession': {'major': 'IT', 'branch': 'Cloud Computing'}},
#  {'ID': '8',
#   'age': 50,
#   'home_address': {'province': 'PN5', 'district': 'Gulmi'},
#   'foreign_address': 'Guyana',
#   'profession': {'major': 'Agriculture', 'branch': 'Vegetable'}},
#  {'ID': '4',
#   'age': 30,
#   'home_address': {'province': 'PN3', 'district': 'Makwanpur'},
#   'foreign_address': 'Tajikistan',
#   'profession': {'major': 'Business', 'branch': 'Stationary'}},
#  {'ID': '2',
#   'age': 47,
#   'home_address': {'province': 'PN4', 'district': 'Baglung'},
#   'foreign_address': 'Nigeria',
#   'profession': {'major': 'Research', 'branch': 'Physics'}},
#  {'ID': '6',
#   'age': 44,
#   'home_address': {'province': 'PN5', 'district': 'Dang'},
#   'foreign_address': 'Brazil',
#   'profession': {'major': 'Business', 'branch': 'Food Industry'}},
#  {'ID': 'T',
#   'age': 50,
#   'home_address': {'province': 'PN1', 'district': 'Morang'},
#   'foreign_address': 'Portugal',
#   'profession': {'major': 'Business', 'branch': 'Stationary'}},
#  {'ID': '7',
#   'age': 41,
#   'home_address': {'province': 'PN2', 'district': 'Mahottari'},
#   'foreign_address': 'Mongolia',
#   'profession': {'major': 'Teaching', 'branch': 'Physics'}},
#  {'ID': 'G',
#   'age': 31,
#   'home_address': {'province': 'PN5', 'district': 'Eastern_Rukum'},
#   'foreign_address': 'Dominican Republic',
#   'profession': {'major': 'Business', 'branch': 'Food Industry'}},
#  {'ID': 'M',
#   'age': 31,
#   'home_address': {'province': 'PN2', 'district': 'Rautahat'},
#   'foreign_address': 'Armenia',
#   'profession': {'major': 'IT', 'branch': 'Cloud Computing'}},
#  {'ID': 'X',
#   'age': 34,
#   'home_address': {'province': 'PN7', 'district': 'Dadeldhura'},
#   'foreign_address': 'Guinea Bissau',
#   'profession': {'major': 'Business', 'branch': 'Stationary'}},
#  {'ID': 'C',
#   'age': 26,
#   'home_address': {'province': 'PN5', 'district': 'Eastern_Rukum'},
#   'foreign_address': 'Ireland',
#   'profession': {'major': 'Research', 'branch': 'Physics'}},
#  {'ID': '8',
#   'age': 39,
#   'home_address': {'province': 'PN5', 'district': 'Pyuthan'},
#   'foreign_address': 'Tunisia',
#   'profession': {'major': 'Research', 'branch': 'Math'}},
#  {'ID': '8',
#   'age': 42,
#   'home_address': {'province': 'PN2', 'district': 'Bara'},
#   'foreign_address': 'Burundi',
#   'profession': {'major': 'Doctor', 'branch': 'Vetenary'}},
#  {'ID': '5',
#   'age': 46,
#   'home_address': {'province': 'PN5', 'district': 'Bardiya'},
#   'foreign_address': 'Zambia',
#   'profession': {'major': 'Agriculture', 'branch': 'Sugarcane'}},
#  {'ID': '6',
#   'age': 38,
#   'home_address': {'province': 'PN6', 'district': 'Western_Rukum'},
#   'foreign_address': 'Iran',
#   'profession': {'major': 'Doctor', 'branch': 'Vetenary'}},
#  {'ID': 'X',
#   'age': 50,
#   'home_address': {'province': 'PN2', 'district': 'Saptari'},
#   'foreign_address': 'Belarus',
#   'profession': {'major': 'Research', 'branch': 'Physics'}},
#  {'ID': '5',
#   'age': 41,
#   'home_address': {'province': 'PN7', 'district': 'Dadeldhura'},
#   'foreign_address': 'Netherlands',
#   'profession': {'major': 'Business', 'branch': 'Stationary'}},
#  {'ID': 'Y',
#   'age': 29,
#   'home_address': {'province': 'PN2', 'district': 'Parsa'},
#   'foreign_address': 'Slovenia',
#   'profession': {'major': 'Research', 'branch': 'Math'}},
#  {'ID': 'V',
#   'age': 33,
#   'home_address': {'province': 'PN3', 'district': 'Kabrepalanchok'},
#   'foreign_address': 'Vanuatu',
#   'profession': {'major': 'Teaching', 'branch': 'Physics'}},
#  {'ID': '1',
#   'age': 40,
#   'home_address': {'province': 'PN3', 'district': 'Ramechaap'},
#   'foreign_address': 'Jordan',
#   'profession': {'major': 'Agriculture', 'branch': 'Goat Farm'}},
#  {'ID': 'P',
#   'age': 26,
#   'home_address': {'province': 'PN6', 'district': 'Jumla'},
#   'foreign_address': 'Czech Republic',
#   'profession': {'major': 'Business', 'branch': 'Stationary'}},
#  {'ID': 'T',
#   'age': 43,
#   'home_address': {'province': 'PN4', 'district': 'Baglung'},
#   'foreign_address': 'Eritrea',
#   'profession': {'major': 'IT', 'branch': 'Software'}},
#  {'ID': 'D',
#   'age': 50,
#   'home_address': {'province': 'PN2', 'district': 'Siraha'},
#   'foreign_address': 'Ghana',
#   'profession': {'major': 'IT', 'branch': 'Full Stack'}},
#  {'ID': 'D',
#   'age': 35,
#   'home_address': {'province': 'PN6', 'district': 'Western_Rukum'},
#   'foreign_address': 'Saudi Arabia',
#   'profession': {'major': 'Doctor', 'branch': 'Vetenary'}},
#  {'ID': 'U',
#   'age': 30,
#   'home_address': {'province': 'PN7', 'district': 'Darchula'},
#   'foreign_address': 'Ghana',
#   'profession': {'major': 'Agriculture', 'branch': 'Vegetable'}},
#  {'ID': '4',
#   'age': 46,
#   'home_address': {'province': 'PN1', 'district': 'Morang'},
#   'foreign_address': 'Kazakhstan',
#   'profession': {'major': 'Doctor', 'branch': 'Vetenary'}},
#  {'ID': '2',
#   'age': 26,
#   'home_address': {'province': 'PN5', 'district': 'Gulmi'},
#   'foreign_address': 'Lebanon',
#   'profession': {'major': 'IT', 'branch': 'Cloud Computing'}},
#  {'ID': '1',
#   'age': 30,
#   'home_address': {'province': 'PN6', 'district': 'Western_Rukum'},
#   'foreign_address': 'Belgium',
#   'profession': {'major': 'Business', 'branch': 'Food Industry'}},
#  {'ID': '5',
#   'age': 40,
#   'home_address': {'province': 'PN5', 'district': 'Eastern_Rukum'},
#   'foreign_address': 'Niger',
#   'profession': {'major': 'Business', 'branch': 'Stationary'}},
#  {'ID': '0',
#   'age': 48,
#   'home_address': {'province': 'PN2', 'district': 'Mahottari'},
#   'foreign_address': 'Latvia',
#   'profession': {'major': 'Agriculture', 'branch': 'Sugarcane'}},
#  {'ID': '8',
#   'age': 31,
#   'home_address': {'province': 'PN6', 'district': 'Mugu'},
#   'foreign_address': 'Nigeria',
#   'profession': {'major': 'Teaching', 'branch': 'English'}},
#  {'ID': 'C',
#   'age': 48,
#   'home_address': {'province': 'PN2', 'district': 'Dhanusha'},
#   'foreign_address': 'Spain',
#   'profession': {'major': 'Research', 'branch': 'Chemistry'}},
#  {'ID': 'G',
#   'age': 33,
#   'home_address': {'province': 'PN2', 'district': 'Rautahat'},
#   'foreign_address': 'Mali',
#   'profession': {'major': 'Teaching', 'branch': 'English'}},
#  {'ID': '0',
#   'age': 48,
#   'home_address': {'province': 'PN1', 'district': 'Bhojpur'},
#   'foreign_address': 'Colombia',
#   'profession': {'major': 'Agriculture', 'branch': 'Goat Farm'}},
#  {'ID': '7',
#   'age': 32,
#   'home_address': {'province': 'PN2', 'district': 'Dhanusha'},
#   'foreign_address': 'Ukraine',
#   'profession': {'major': 'Doctor', 'branch': 'Vetenary'}}]
